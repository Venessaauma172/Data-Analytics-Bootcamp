# %%
import pandas as pd

# %%
car=pd.read_excel("Car data saved-1.xlsx")
car.head()
# Out:
#                Name  Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  \
# 0     Mahindra Thar             11.35             17.60         15.20  1497
# 1      Maruti Swift              6.49              9.60         24.80  1197
# 2  Mahindra Scorpio             13.62             17.42         22.00  2184
# 3        Tata Punch              6.13             10.20         20.09  1199
# 4     Hyundai Creta             11.00             20.15         17.40  1497
#
#    Seats  Variants     Type  Ex-Showroom Price       RTO  Insurance  Other  \
# 0      4        19   Petrol            1430000  143000.0    84367.0  14300
# 1      5        11   Petrol             649000   46240.0    27791.0   5485
# 2      7         4  Diesel             1361600  175000.0    85943.0  27532
# 3      5        25   Petrol             612900   42903.0    35311.0      0
# 4      5        28   Petrol            1099900  116863.0    45300.0  11599
#
#   Onroad Price
# 0    16,71,667
# 1     7,28,516
# ...

# %%
pivot=car.pivot_table(index="Name",columns="Type",values="Onroad Price",aggfunc="min")
pivot
# Out:
# Type                        Diesel        Petrol
# Name
# Hyundai Creta                   NaN    12,73,662
# Hyundai Exter                   NaN     6,98,009
# Kia Seltos                      NaN    12,42,525
# Land Rover Defender             NaN  1,11,70,278
# Land Rover Range Rover  2,77,25,295          NaN
# Mahindra Bolero           11,12,348          NaN
# Mahindra Scorpio          16,50,075          NaN
# Mahindra Scorpio N              NaN    16,13,522
# Mahindra Thar                   NaN    16,71,667
# Mahindra XUV 3XO                NaN     8,41,750
# Mahindra XUV700                 NaN    16,36,062
# Maruti Baleno                   NaN     7,51,770
# Maruti Brezza                   NaN     9,32,544
# Maruti Ertiga                   NaN     9,68,665
# Maruti FRONX                    NaN     8,39,546
# Maruti Swift                    NaN     7,28,516
# Tata Harrier              17,88,393          NaN
# Tata Nexon                      NaN     8,98,185
# ...

# %%
pivot=car.pivot_table(
    index="Name",columns="Type",
    values=["Onroad Price","Ex-Showroom Price"],
    aggfunc="min").fillna(0)
pivot
# Out:
#                        Ex-Showroom Price            Onroad Price
# Type                             Diesel      Petrol      Diesel        Petrol
# Name
# Hyundai Creta                        0.0  1099900.0            0    12,73,662
# Hyundai Exter                        0.0   612800.0            0     6,98,009
# Kia Seltos                           0.0  1089900.0            0    12,42,525
# Land Rover Defender                  0.0  9700000.0            0  1,11,70,278
# Land Rover Range Rover        23600000.0        0.0  2,77,25,295            0
# Mahindra Bolero                 979400.0        0.0    11,12,348            0
# Mahindra Scorpio               1361600.0        0.0    16,50,075            0
# Mahindra Scorpio N                   0.0  1385199.0            0    16,13,522
# Mahindra Thar                        0.0  1430000.0            0    16,71,667
# Mahindra XUV 3XO                     0.0   749000.0            0     8,41,750
# ...

# %%
Preference=pd.DataFrame(
    {
        "Preference":['Yes','No'],
     "Type":['Petrol','Diesel']
    }
)
Preference
# Out:
#   Preference    Type
# 0        Yes  Petrol
# 1         No  Diesel

# %%
merged_df=pd.merge(car,Preference,on='Type',how="left")
merged_df.head()
# Out:
#                Name  Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  \
# 0     Mahindra Thar             11.35             17.60         15.20  1497
# 1      Maruti Swift              6.49              9.60         24.80  1197
# 2  Mahindra Scorpio             13.62             17.42         22.00  2184
# 3        Tata Punch              6.13             10.20         20.09  1199
# 4     Hyundai Creta             11.00             20.15         17.40  1497
#
#    Seats  Variants     Type  Ex-Showroom Price       RTO  Insurance  Other  \
# 0      4        19   Petrol            1430000  143000.0    84367.0  14300
# 1      5        11   Petrol             649000   46240.0    27791.0   5485
# 2      7         4  Diesel             1361600  175000.0    85943.0  27532
# 3      5        25   Petrol             612900   42903.0    35311.0      0
# 4      5        28   Petrol            1099900  116863.0    45300.0  11599
#
#   Onroad Price Preference
# 0    16,71,667        Yes
# ...

# %%
car['Type'].unique()
# Out:
# array(['Petrol', 'Diesel\xa0'], dtype=object)

# %%
df =DataFrame.replace('Diesel\xa0','Diesel')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df =DataFrame.replace('Diesel\xa0','Diesel')
#
# NameError: name 'DataFrame' is not defined

# %%
DataFrame.set_index("Type")
Preference.set_index("Type")
DataFrame.join(Preference)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 DataFrame.set_index("Type")
#       2 Preference.set_index("Type")
#       3 DataFrame.join(Preference)
#
# NameError: name 'DataFrame' is not defined

# %%
df.set_index('Type').join(Preference.set_index('Type'))
joined.reset_index()
